# %% [markdown]
# #  <font color=red> Module_09_List</font>

# %% [markdown]
# # P9-3
# ## List &rArr; 有序(sequence)、可變(mutable)
# >### P3-3<img src='./img/py_data_type.png'>

# %%
list1=['a', 'b', 'c', 'd']
print(list1)
list2='a b c d'.split() # 講義P5-13
print(list2)
list3 = ['bdse', 'aien', 2015, 2018]
print(list3)
list4 = [1, 2, 3, 4, 5]
print(list4)

# %% [markdown]
# ----

# %% [markdown]
# # P9-4
# # index
# ><img src=".\img\list.png"  style='height:250px; width:650px'>

# %%
names=['fraser', 'grace', 'john', 'jess', 'jack', 23.5, 2019]
print('id of names :            ', id(names))
print('names =                  ', names)
print('names[0] =               ', names[0])
print('names[0][0] =            ', names[0][0], '\n')

print('names[5] =               ', names[5])
print('names[-1] =              ', names[-1],'\n')

print('names[1:5] =             ', names[1:5])
print('names[1:6:2] =           ', (names[1:6:2]))
# Out:
# id of names :             2491042445760
# names =                   ['fraser', 'grace', 'john', 'jess', 'jack', 23.5, 2019]
# names[0] =                fraser
# names[0][0] =             f
#
# names[5] =                23.5
# names[-1] =               2019
#
# names[1:5] =              ['grace', 'john', 'jess', 'jack']
# names[1:6:2] =            ['grace', 'jess', 23.5]

# %% [markdown]
# ---

# %% [markdown]
# # P9-5

# %% [markdown]
# ## List 是可變的資料結構
# ><img src='./img/list_mutable.png' style= height:450px>
# ## 比較 mutable & immutable 資料結構
# >P3-10<img src='./img/py_reference.gif' style= height:450px>

# %%
names=['fraser', 'grace', 'john', 'jess', 'jack', 23.5, 2019]
print('id of names :            ', id(names))

names[2]='Kevin'
print("names[2]='Kevin' :       ", names) # 修改

names[-1:]=[2000, 23.5] # 一次改兩筆資料
print('names[-1:]=[2000, 23.5] :', names) #list 可增加直接擴大

print('id of names :            ', id(names))

# %% [markdown]
# ## P4-9:
# <img src='./img/is_equal.png' style='height:400px'>

# %%
li1=[1,2]
li2=li1.copy()
print('li2 id:', id(li2))
print('li1 id:', id(li1))
print('li2 == li1:', li2==li1)
print('li2 is li1:', li2 is li1) # 數值雖然相同, 但記憶體位置不同

# %% [markdown]
# ---

# %% [markdown]
# # P9-6
# ## List裡的內容可以放入任何結構 &rArr; List裡面就可以放入多層次的資料
# >![listNested](.\img\listNested.png)

# %%
x=['a', ['bb', ['ccc', 'ddd'], 'ee', 'ff'], 'g', ['hh', 'ii'], 'j']
print('x[1] :      ', x[1])
print('x[1][1] :   ', x[1][1])
print('x[1][1][0] :', x[1][1][0])
print('x[3] :      ', x[3])

# %% [markdown]
# ---

# %% [markdown]
# # P9-8

# %%
[1, 2, 3] + [4, 5, 6]

# %%
['Hi!'] * 4

# %%
30 in [10, 20, 30]

# %%
a = [10, 20, 30]
for x in a: 
    print (x, end = ' ')

# %%
lst=[11, 22, 33, 44]
print('id(lst) :                   ', id(lst), '\n')

lst[2:]=[333,444,555,666]  #list 可增加直接擴大
print('lst[2:] = :                 ', lst)
print('id(lst) :                   ', id(lst), '\n')

# %% [markdown]
# ---

# %% [markdown]
# # P9-12

# %%
lst=[20, 10, 30]

print('lst =                       ', lst)
print('len(lst) :                  ', len(lst))
print('max(lst) :                  ', max(lst))
print('min(lst) :                  ', min(lst))
print('sum(lst) :                  ', sum(lst))
print('sorted(lst):                ', sorted(lst))
print('sorted(lst, reverse=True) : ', sorted(lst, reverse=True))

# %%
list('abcd')

# %% [markdown]
# ---

# %% [markdown]
# # P9-14

# %%
a = [4, 777, 444, 999, 11, 4]

print('id of a :                 ', id(a))

a.append('1')
print('a.append(1) :             ', a)

b = a.count(4)
print('a.count(4) :              ', b)

c = a.copy()
print('id of c :                 ', id(c))

a.clear()
print('a.clear() :               ', a)

# %% [markdown]
# ---

# %% [markdown]
# # P9-15

# %%
a = [4, 777, 444, 999, 11, 45, 999, 66, 88, 73]
b = ['aa', 'bb', 'cc']
a.extend(b)
print('a.extend(b) :             ', a)

print('a.index(999) :            ', a.index(999))

a.insert(5, 555)
print('a.insert(5, 555) :        ', a)

a.pop()                                       #刪除
print('a.pop() :                 ', a)        

a.pop(4)                                      #刪除
print('a.pop(4) :                ', a)

# %%
a = [4, 777, 444, 999, 11, 45, 999, 66, 88, 73]

b = a.pop()
print(b)
print(a)

c = a.pop()
print(c)
print(a)

# %%
x=[1,2]
y=[3,4]
x[len(x):]=y
x
# Out:
# [1, 2, 3, 4]

# %% [markdown]
# ---

# %% [markdown]
# # P9-16

# %%
a = [4, 777, 444, 999, 11, 45, 66, 88, 73]

a.remove(11)                                #刪除
print('a.remove(11) :          ', a, '\n')

a.reverse()
print('a.reverse :               ', a)

# %%
b = ['saw', 'small', 'He', 'foxes', 'six']
b.sort(key=len)  # length
b
# Out:
# ['He', 'saw', 'six', 'small', 'foxes']

# %%
b.sort(key=max)
print(b)
print(max('six'),max('He'))
# Out:
# ['He', 'small', 'saw', 'six', 'foxes']
# x e

# %% [markdown]
# ---

# %% [markdown]
# # &spades; 補充
# <img src='./img/list_reference.png' style='height:400px'>

# %%
names=['fraser', 'grace', 'john', 'jess', 'jack', 23.5, 2019]
names2 = names
print(id(names),id(names2))

names2[2]='Kevin' # 更改names2，但是因為names2與names是參考到同一個記憶體位置，所以names會一起被修改。
print(names)
