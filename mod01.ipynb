# %% [markdown]
# #  <font color=red> Module_01_Python簡介</font>

# %% [markdown]
# # P1-3, Python 特性
# >### 程式導向(Procedural Programging Paradigms)
# >- 易於維護
# >- 讓程式碼可以重複使用
# ><img src="./img/pop_hierarchy_2.png" style='height:400px; width:800px'><br>
# ><img src="./img/pop_hierarchy.png" style='height:300px; width:600px'><br>
#
# >### 物件導向(Object-Oriented Programging Paradigms)
# >- 讓程式碼易於理解
# >- 通過將程式碼化為物件的方式，令程式之間互相傳遞資訊
# ><img src="./img/oop_example.png" style='height:300px; width:600px'><br>
# >- 這些設計模式並不互相衝突[ref](https://www.freecodecamp.org/news/an-introduction-to-programming-paradigms/)
#
# >### 程式發展歷史
# ><img src="./img/oop_history.png" style='height:300px; width:600px'><br>
#
# >### 腳本語言的特點
# >- #### 一個enter 執行一行敘述
# >- #### 可以把一個程式中的多個區段分開執行，其效果等同於一起執行所有區段的程式。

# %% [markdown]
# # P1-4
# ### 程式語言的成長趨勢
# ><img src="./img/PythonTrend.png"  style='height:450px; width:900px'>
#
# [ref 1](https://insights.stackoverflow.com/trends)
# [ref 2](https://www.tiobe.com/tiobe-index/)

# %% [markdown]
# # P1-5
# ## python 安裝
# <details>
#     <summary>使用官網python</summary>
#     <details>
#         <summary style="text-indent: 1em;">Windows</summary>
#         <ol style="text-indent: 2em;">
#             <li>把「Add Python 3.x to PATH」的選取方塊打勾，這樣的目的是為了讓Windows可以找到Python，我們的課程將以純的Python環境進行開發。</li>
#             <li>接著點擊「Customize installation」。</li>
#             <li>在Optional Features頁面內，把所有核取方塊打勾。</li>
#             <li>下一步進到「Advanced Options」，把「install for all users」的核取方塊打勾，其他的核取方塊則維持預設值。</li>
#             <li>安裝後，要記得點擊「Disable path length limit」(如果沒有出現此按鈕代表之前已經有設定過了)。</li>
#         </ol>
#         <details>
#             <summary style="text-indent: 2em;">image</summary>
#             <img style="margin-left: 3em;" src='./img/python_org_install_windows.png' style='height:500px'>
#         </details>
#     </details>
#     <details>
#         <summary style="text-indent: 1em;">Mac</summary>
#         <ol style="text-indent: 2em;">
#             <li>在簡介頁面上，點擊繼續</li>
#             <li>在請先閱讀頁面上，點擊繼續</li>
#             <li>在許可證頁面上，點擊繼續</li>
#             <li>在安裝類型頁面上，點擊繼續，接著系統會要求你輸入使用者密碼</li>
#         </ol>
#         <details>
#             <summary style="text-indent: 2em;">image</summary>
#             <img style="margin-left: 3em;" src='./img/python_org_install_mac.png' style='height:500px'>
#         </details>
#     </details>
# </details>
# <hr>
# <details>
#     <summary>使用anaconda</summary>
#     <details>
#         <summary>anaconda簡介</summary>
#         <ol>
#             <li>使用者可以藉由 Anaconda 來針對不同專案創建虛擬環境</li>
#             <ol>
#                 <li>更易於管理不同專案</li>
#                 <li>避免多個專案同時進行，軟體之間會產生版本衝突</li>
#                 <li>
#                     <details>
#                         <summary>image</summary>
#                         <img src='./img/anaconda_environment.png' style='height:500px'>
#                     </details>
#                 </li>
#             </ol>
#         </ol>
#     </details>
#     <details>
#         <summary>安裝 Anaconda</summary>
#         <img src='./img/anaconda_install1.png' style='height:500px'>
#         <img src='./img/anaconda_install2.png' style='height:500px'>
#         <img src='./img/anaconda_install3.png' style='height:500px'>
#     </details>
# </details>

# %% [markdown]
# # P1-7
# 1. Python 不需要事先宣告變數
# 2. Python 不需要指定變數的型態
# 3. 變數賦值(建立)<font color=red>後</font>即可直接使用

# %% [markdown]
# # P1-8
# ## 命令提示字元cmd(windows)/終端機terminal(linux, macOS)
# ## 命令提示字元常用指令
# - ## 變更目錄: `cd` / `cd`
# - ## 查詢目錄: `dir` / `ls`
# - ## 離開cmd: `exit` / `exit`
#
# ## cmd/terminal Python相關指令
# - ### `python -h` ⇒查看所有在cmd中的python指令說明
# - ### `python -V`(大寫V) ⇒查看版本(模仿linux指令)
# ---
# ## 使用Anaconda開啟命令提示字元(虛擬環境下)
# <details>
#     <summary>圖示</summary>
#     <img src='./img/anaconda_env1.png' style='height:500px'>
#     <img src='./img/anaconda_env2.png' style='height:500px'>
#     <img src='./img/anaconda_env3.png' style='height:500px'>
#     <img src='./img/anaconda_env4.png' style='height:500px'>
#     <img src='./img/anaconda_env5.png' style='height:500px'>
# </details>
#
#
# ---
# ## Python shell
# - ### `＞＞＞` &rArr; Python的命令提示字元(可以輸入指令的地方)
# - ### `．．．` &rArr; Python的第二提示字元
# - ### `exit()` &rArr; 離開Python shell，是Python的內建function
# ---
# ## 如何執行Python程式檔案(.py)
# ### `python XXX.py`
# >### PS. “.ipynb” 結尾的檔案並不是python腳本檔，而是jupyter notebook的筆記本檔案。可以使用jupyter notebook或是VS code 開啟。
#
# ---
# ## print(variable) 與 直接呼叫variable的差異:
# - ### 直接呼叫variable &rArr; 受益於Python shell 是互動式的，所以才可以直接呼叫變數

# %% [markdown]
# ### <font color=red>請注意，使用print()時數字還是文字容易弄混

# %%
y = 123
x = '123'
print(y)
print(x)

# %%
x

# %%
y

# %% [markdown]
# ---

# %% [markdown]
# # P1-9 IDE (開發工具箱)
# - ## VS code
# - ## Jupyter notebook/Jupyter lab (網站架構<HTML>)

# %% [markdown]
# ## VScode
# <details>
#     <summary style="font-size: 1.5em; text-indent: 1em;">在VScode上安裝讀取python腳本檔(<code>.py</code>)的外掛</summary>
#     <div style="text-indent: 2em;">由於VS Code不知道Python的安裝路徑，<font color=red>所以當開啟任一個.py檔案時，VS Code會提示你進行設定。</font>此時我們只要按照下圖的步驟，去設定Python.exe的路徑即可。</div>
#     <ol style="margin-left: 2em;">
#         <li>
#             安裝Python extension
#             <details>
#                 <summary>image</summary>
#                 <img style="margin-left: 2em; height: 500px;" src='./img/vscode_py_ext.png'>
#             </details>
#         </li>
#         <li>
#             開啟資料夾並新增或讀取<code>.py</code>檔
#             <details>
#                 <summary>讀取</summary>
#                 <img style="margin-left: 2em; height:500px;" src='./img/vscode_open_folder.png'><br>
#             </details>
#             <details>
#                 <summary>新增</summary>
#                 <img style="margin-left: 2em; height:500px;" src='./img/vscode_create_py.png'><br>
#             </details>
#         </li>
#         <li>
#             設定Python.exe的路徑
#             <details>
#                 <summary>image</summary>
#                 <img style="margin-left: 2em; height:500px;" src='./img/vscode_set_py.png'><br>
#             </details>
#         </li>
#     </ol>
# </details>
# <details>
#     <summary style="font-size: 1.5em; text-indent: 1em;">在VScode上安裝讀取jupyter notebook檔案(<code>.ipynb</code>)的外掛</summary>
#     <div style="text-indent: 2em;"><code>.ipynb</code>是jupyter notebook的檔案，但也可藉由VScode的外掛來讀取</div>
#     <ol style="margin-left: 2em;">
#         <li>
#             安裝Jupyter extension
#             <details>
#                 <summary>image</summary>
#                 <img style="margin-left: 2em; height:500px;" src='./img/vscode_jupyter_ext.png'>
#             </details>
#         </li>
#         <li>
#             開啟資料夾並新增或讀取<code>.ipynb<code>檔
#         </li>
#     </ol>
# </details>

# %% [markdown]
# ## Jupyter notebook/Jupyter lab
# <details>
#     <summary style="font-size: 1.5em; text-indent: 1em;">數種安裝Jupyter notebook/Jupyter lab的方式</summary>
#     <details>
#         <summary style="text-indent: 2em;">使用pip安裝Jupyter notebook(需要另外訂定環境變數)</summary>
#         <ol style="margin-left: 2em;">
#             <li>
#                 透過終端機輸入安裝jupyter notebook的指令
#                 <details>
#                     <summary>(windows)以<font color=red>系統管理員身分</font>的身分在命令提示字元中輸入指令: <code>pip install jupyter notebook</code> (安裝程式都用系統管理員身分)</summary>
#                     <img  style="margin-left: 2em;" src="img/jupyter_install1.png">
#                     <img  style="margin-left: 2em;" src="img/jupyter_install2.png">
#                 </details>
#                 <details>
#                     <summary>(macOS) 請在terminal中輸入<code>sudo pip3 install jupyter notebook</code></summary>
#                         <div>在terminal輸入<code>sudo pip3 install jupyter notebook</code>，接著輸入登入系統時的密碼(輸入時terminal不會顯示)，輸入完密碼後按enter 即可</div>
#                     <img src="img/mac_terminal.jpg">
#                 </details>
#             </li>
#             <li>
#                 安裝完成後(看到<font color=red>C:\WINDOWS\system32</font>才代表安裝完成)再輸入<code>exit</code>退出命令提示字元(macOS 也是輸入<code>exit</code>)
#                 <details>
#                 <summary>image</summary>
#                 <img src="img/jupyter_install3.png">
#             </details>
#             </li>
#             <li>啟動Jupyter notebook
#                 <ol>
#                     <li>
#                         開啟終端機
#                         <ul>
#                             <li>
#                                 <details>
#                                     <summary>(windows) 開啟教材資料夾，並在路徑列輸入<code>cmd</code>，以<font color=red>一般使用者</font>的身分開啟終端機並移動至教材資料夾</summary>
#                                     <img src="img/jupyter_install4.png">
#                                 </details>
#                             </li>
#                             <li>
#                                 (macOS) 請將教材資料夾放在桌面，並開啟一個新的terminal
#                             </li>
#                         </ul>
#                     </li>
#                     <li>透過終端機輸入開啟jupyter notebook的指令
#                         <ul>
#                             <li>(windows) 在命令提示字元中輸入指令 <code>jupyter notebook</code> (執行程式用一般身分即可)</li>
#                             <li>
#                                 <details>
#                                     <summary>(macOS) 參考下列步驟</summary>
#                                     <ol>
#                                         <li>將教材資料夾(以zip檔的形式)下載後，放到桌面上</li>
#                                         <li>開啟 terminal後輸入<code>jupyter notebook</code></li>
#                                         <li>請輸入完後到Desktop裡找教材資料夾即可
#                                             <details>
#                                                 <img src="img/mac_jupyter_notebook.png">
#                                             </details>
#                                         </li>
#                                     </ol>
#                                 </details>
#                             </li>
#                         </ul>
#                     </li>
#                 </ol>
#             </li>
#         </ol>
#     </details>
#     <hr>
#     <details>
#         <summary style="text-indent: 2em;">使用pip安裝Jupyter Lab(需要另外訂定環境變數)</summary>
#         <ol style="margin-left: 2em;">
#             <li>
#                 透過終端機輸入安裝jupyter lab的指令
#                 <details>
#                     <summary>(windows)以<font color=red>系統管理員身分</font>的身分在命令提示字元中輸入指令: <code>pip install jupyterlab</code> (安裝程式都用系統管理員身分)</summary>
#                     <img style="margin-left: 2em;" src="img/jupyter_install1.png">
#                     <img style="margin-left: 2em;" src="img/jupyter_lab_install2.png"  width="2000">
#                 </details>
#                 <details>
#                     <summary>(macOS) 請在terminal中輸入<code>sudo pip3 install jupyterlab</code></summary>
#                         <div>在terminal輸入<code>sudo pip3 install jupyterlab</code>，接著輸入登入系統時的密碼(輸入時terminal不會顯示)，輸入完密碼後按enter 即可</div>
#                     <img src="img/mac_terminal.jpg">
#                 </details>
#             </li>
#             <li>
#                 安裝完成後(看到<font color=red>C:\WINDOWS\system32</font>才代表安裝完成)再輸入<code>exit</code>退出命令提示字元(macOS 也是輸入<code>exit</code>)
#                 <details>
#                 <summary>image</summary>
#                 <img src="img/jupyter_install3.png">
#             </details>
#             </li>
#             <li>啟動Jupyter Lab
#                 <ol>
#                     <li>開啟終端機
#                         <ul>
#                             <li>
#                                 <details>
#                                     <summary>(windows) 開啟教材資料夾，並在路徑列輸入<code>cmd</code>以<font color=red>一般使用者</font>的身分開啟</summary>
#                                     <img src="img/jupyter_install4.png">
#                                 </details>
#                             </li>
#                             <li>(macOS) 請將教材資料夾放在桌面，並開啟一個新的terminal</li>
#                         </ul>
#                     </li>
#                     <li>透過終端機輸入開啟jupyter lab的指令
#                         <ul>
#                             <li>(windows) 在命令提示字元中輸入指令 <code>jupyter lab</code> (執行程式用一般身分即可)</li>
#                             <li>
#                                 <details>
#                                     <summary>(macOS) 參考下列步驟</summary>
#                                     <ol>
#                                         <li>將教材資料夾(以zip檔的形式)下載後，放到桌面上</li>
#                                         <li>開啟 terminal後輸入<code>jupyter lab</code></li>
#                                         <li>請輸入完後到Desktop裡找教材資料夾即可
#                                             <details>
#                                                 <img src="img/mac_jupyter_notebook.png">
#                                             </details>
#                                         </li>
#                                     </ol>
#                                 </details>
#                             </li>
#                         </ul>
#                     </li>
#                 </ol>
#             </li>
#         </ol>
#     </details>
#     <hr>
#     <details style="text-indent: 2em;">
#         <summary>使用anaconda安裝jupyter notebook</summary>
#         <img src="img/anaconda_jupyter.png">
#     </details>
# </details>
# <details>
#     <summary style="font-size: 1.5em; text-indent: 1em;">Jupyter notebook/ Jupyter Lab 介紹</summary>
#     <div style="font-size: 1.25em; text-indent: 2em;">Jupyter notebook/ Jupyter Lab 是一個互動式筆記本，本質是一個Web 應用程式，主頁面由許多Cell組成</div>
#     <ul style="margin-left: 2em">
#         <li style="font-size: 1.125em;">Ipython 就是 Jupyter Python 的 Kernel (ipython : 互動式)</li>
#         <li style="font-size: 1.125em;">Cell &rArr; 每一個Cell都是可以執行的區塊，裡面可以輸入程式碼
#             <ul>
#                 <li>
#                     <details>
#                         <summary>功能分類說明</summary>
#                         <ol>
#                             <li>Code cells &rArr; 用來寫 code 所使用的</li>
#                             <li>Markdown cells &rArr; 用來作筆記用的</li>
#                         </ol>
#                         <img src="./img/cell_utility.png">
#                     </details>
#                 </li>
#                 <li>
#                     <details>
#                         <summary>Cell模式說明</summary>
#                         <ol>
#                             <li>命令模式(Cell外框以藍色顯示)</li>
#                             <li>編輯模式(Cell外框以綠色(jupyter lab 則依舊維持藍色)顯示，且會有游標閃動)</li>
#                         </ol>
#                     </details>
#                 </li>
#             </ul>
#         </li>
#     </ul>
# </details>
# <details>
#     <summary style="font-size: 1.5em; text-indent: 1em;">Jupyter notebook/ Jupyter Lab 常用功能</summary>
#     <ul style="font-size: 1.25em; margin-left: 2em;">
#         <li>
#             <details>
#                 <summary>快捷鍵</summary>
#                 <ul>
#                     <li>(Jupyter notebook) Help &rarr;  Keybosrd ShortCuts</li>
#                     <li>(Jupyter Lab) Settints &rarr; Advanced settings &rarr; Keybosrd ShortCuts</li>
#                     <li>
#                         <details>
#                         <summary>Common Jupyter Keyboard ShortCuts</summary>
#                             <p>
#                                 <img src='./img/hotkey_commend.png' style='height:500px'>
#                                 <img src='./img/hotkey_edit.png' style='height:300px'>
#                             </p>
#                         </details>
#                     </li>
#                 </ul>
#             </details>
#         </li>
#         <li><code>Tab</code> &rArr; auto compelete(自動補字)</li>
#         <li><code>shift</code> + <code>Tab</code> &rArr; 快速查詢函式、方法的用法</li>
#         <li><code>?</code> &rArr; 查看說明文件</li>
#         <li><code>%</code> &rArr; jupyter的魔法函式</li>
#         <li><code>!</code> + cli 指令 &rArr; 執行作業系統命令</li>
#     </ul>
# </details>
# <details>
#     <summary style="font-size: 1.5em; text-indent: 1em;">關閉Jupyter notebook/ Jupyter Lab</summary>
#     <ul style="font-size: 1.25em; margin-left: 2em;">
#         <li>關閉Jupyter的Server(通常以cmd介面執行) &rArr; <code>Ctrl</code> + <code>C</code></li>
#         <li>關閉瀏覽器頁簽 &rArr; 直接關閉即可</li>
#     </ul>
# </details>

# %%
print

# %%
print?

# %%
# %timeit print('Hi')

# %%
# !dir

# %% [markdown]
# ---

# %% [markdown]
# ### 在Jupyter notebook的Cell中呼叫變數的話，只會出現最後一個結果，如果要在一個Cell內列印出多個變數的數值 &rArr; `print()`

# %%
a = 10
b = 20
a
b

# %%
a = 10
b = 20
print(a)
print(b)

# %% [markdown]
# ---
# # &spades; 補充

# %% [markdown]
# # 靜態語言&動態語言 說明
# >## 具體來說，<font color =red>靜態語言</font>是指變數是否帶有資料型態，反之則為<font color =green>動態語言</font>。
# >>### - <font color =red>靜態語言</font>寫程序時要聲明所有變量的數據類型
# >>### - <font color =green>動態語言</font>編程不用給任何變量指定數據類型。
# >>### - 省略變數類型宣告動作 &rarr; 動態語言

# %% [markdown]
# # Visual Studio Code-step by step flow debug
# ### 1. 先在Visual Studio Code 適當地設定中斷點, 而在程式執行到某個中斷點就會pause
# >如下圖第2、3行的紅點<img src='./img/vscode_debug_1.png' style='height:400px'>
# ### 2. 再點選上方頁簽的Run &rarr; Start Debugging(或是輸入f5)來執行程式,用f5執行程式,碰到中斷點,程式執行會pause
# >如下圖綠框圈選部分<img src='./img/vscode_debug_2.png' style='height:400px'>
# ### 3.選擇Python檔案 (偵錯目前使用中的檔案)
# >如下圖綠框圈選部分<img src='./img/vscode_debug_3.png' style='height:400px'>
# ### 4.在左邊watch欄位新增要觀察的變數
# >如下圖綠框圈選部分<img src='./img/vscode_debug_4.png' style='height:400px'>
# ### 5.點擊上方的continue按鈕(或是輸入f5)執行程式
# >如下圖綠框圈選部分<img src='./img/vscode_debug_5.png' style='height:400px'>
# ### 6.當程式碼的底色變為黃色時，代表執行到該行程式碼，以此觀察如何變數是如何變化的。
# ><img src='./img/vscode_debug.gif' style='height:400px'>
